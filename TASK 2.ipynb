# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Filling the Age column with median
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df['Age'] = df['Age'].astype(int)

# %%
#Filling the missing values in Embarked with the mode
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
# Drop Cabin because it has nearly 75% of data missing
df.drop(['Cabin'], axis=1, inplace=True)

# %%
# extract title because name has high cardinality
df['Title'] = df['Name'].str.extract(r' ([A-Za-z]+)\.', expand=False)

# %%
# Same for this also ticket column as high cardinality
df['TicketPrefix'] = df['Ticket'].str.extract('([A-Za-z./]+)', expand=False)
df['TicketPrefix'] = df['TicketPrefix'].fillna('None')

# %%
# Adding new feature Familysize
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# %%
df.drop(columns=['Name', 'SibSp', 'Parch', 'Ticket'], inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass     Sex  Age     Fare Embarked Title  \
# 0              1         0       3    male   22   7.2500        S    Mr
# 1              2         1       1  female   38  71.2833        C   Mrs
# 2              3         1       3  female   26   7.9250        S  Miss
# 3              4         1       1  female   35  53.1000        S   Mrs
# 4              5         0       3    male   35   8.0500        S    Mr
# ..           ...       ...     ...     ...  ...      ...      ...   ...
# 886          887         0       2    male   27  13.0000        S   Rev
# 887          888         1       1  female   19  30.0000        S  Miss
# 888          889         0       3  female   28  23.4500        S  Miss
# 889          890         1       1    male   26  30.0000        C    Mr
# 890          891         0       3    male   32   7.7500        Q    Mr
#
#     TicketPrefix  FamilySize
# 0             A/           2
# 1             PC           2
# 2         STON/O           1
# 3           None           2
# 4           None           1
# ..           ...         ...
# 886         None           1
# 887         None           1
# 888        W./C.           4
# 889         None           1
# 890         None           1
#
# [891 rows x 10 columns]

# %%
df = df[['PassengerId', 'Title', 'Sex', 'Age', 'FamilySize',
         'Pclass', 'Fare', 'Embarked', 'TicketPrefix', 'Survived']]
df
# Out:
#      PassengerId Title     Sex  Age  FamilySize  Pclass     Fare Embarked  \
# 0              1    Mr    male   22           2       3   7.2500        S
# 1              2   Mrs  female   38           2       1  71.2833        C
# 2              3  Miss  female   26           1       3   7.9250        S
# 3              4   Mrs  female   35           2       1  53.1000        S
# 4              5    Mr    male   35           1       3   8.0500        S
# ..           ...   ...     ...  ...         ...     ...      ...      ...
# 886          887   Rev    male   27           1       2  13.0000        S
# 887          888  Miss  female   19           1       1  30.0000        S
# 888          889  Miss  female   28           4       3  23.4500        S
# 889          890    Mr    male   26           1       1  30.0000        C
# 890          891    Mr    male   32           1       3   7.7500        Q
#
#     TicketPrefix  Survived
# 0             A/         0
# 1             PC         1
# 2         STON/O         1
# 3           None         1
# 4           None         0
# ..           ...       ...
# 886         None         0
# 887         None         1
# 888        W./C.         0
# 889         None         1
# 890         None         0
#
# [891 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x='Survived', data=df)
plt.title('Survival Count')
plt.xticks([0, 1], ['Not Survived', 'Survived'])
plt.show()

# %%
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title('Survival by Sex')
plt.legend(labels=['Not Survived', 'Survived'])
plt.show()

# %%
sns.countplot(x='Pclass', hue='Survived', data=df)
plt.title('Survival by Pclass')
plt.legend(labels=['Not Survived', 'Survived'])
plt.show()

# %%
sns.histplot(data=df, x='Age', hue='Survived', bins=30, kde=True)
plt.title('Age Distribution by Survival')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
df.describe()
# Out:
#        PassengerId         Age  FamilySize      Pclass        Fare    Survived
# count   891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.345679    1.904602    2.308642   32.204208    0.383838
# std     257.353842   13.028212    1.613459    0.836071   49.693429    0.486592
# min       1.000000    0.000000    1.000000    1.000000    0.000000    0.000000
# 25%     223.500000   22.000000    1.000000    2.000000    7.910400    0.000000
# 50%     446.000000   28.000000    1.000000    3.000000   14.454200    0.000000
# 75%     668.500000   35.000000    2.000000    3.000000   31.000000    1.000000
# max     891.000000   80.000000   11.000000    3.000000  512.329200    1.000000

# %%
df.describe(include=['object'])
# Out:
#        Title   Sex Embarked TicketPrefix
# count    891   891      891          891
# unique    17     2        3           40
# top       Mr  male        S         None
# freq     517   577      646          661

# %%
# Histogram to plot age and fare
df.hist(column=['Age', 'Fare'], figsize=(10, 4), bins=20)
plt.show()

# %%
# Boxplot for Age
df.boxplot(column='Age')
plt.title("Boxplot of Age")
plt.show()

# %%
# Boxplot for Fare
df.boxplot(column='Fare')
plt.title("Boxplot of Fare")
plt.show()

# %%
# Survival rate by Pclass
df.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
# Survival rate by Sex
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64
